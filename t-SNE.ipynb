# %%
import json
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.manifold import TSNE

# %%
data = []
with open('en-train.json','r') as fp:
    for f in fp:
        data.append(json.loads(f))

# %%
data[0:2]
# Out:
# [{'id': 100000,
#   'text': "Schools 'need to adopt green approach'\nPUBLISHED : Monday, 08 March, 1999, 12:00am\nYou are never too young to learn to look after the environment, an official says.\nSpeaking at a seminar on environmental studies held at the Open University of Hong Kong, Mabel Mak Lok-sheung, senior environmental protection officer at the Environmental Protection Department, said concern for the environment should be taught from an early age.\nSchools should adopt a green approach to help create a better living environment, Ms Mak said.\nEnvironmental awareness would penetrate every level of society if children learned it at school, she said.\n'It should be a top-down approach. The first level is the management level.\n'Principals and administrative staff at schools should set an example for teachers ",
#   'label': 0},
#  {'id': 100001,
#   'text': 'IN SCHOOL\nKerber, defending Graf’s record, gets the message\nJanuary 29, 2016 00:00 IST\nAngelique Kerber\nI think she [Serena Williams] ',
#   'label': 0}]

# %%
corpus = [d['text'] for d in data]

vectorizer = TfidfVectorizer()

X = vectorizer.fit_transform(corpus)

labels = [d['label'] for d in data]

labels = np.asarray(labels)

# %%
sum(labels)/len(labels)
# Out:
# 0.20506220506220507

# %%
X_embedded = TSNE(n_components=2, learning_rate='auto',
...                   init='random', perplexity=30).fit_transform(X)

# %%
X_embedded.shape
# Out:
# (9324, 2)

# %%
list_filter = lambda l,v : np.where(l == v)[0]

# %%
plt.scatter(X_embedded[list_filter(labels, 0),0], X_embedded[list_filter(labels, 0),1])
plt.scatter(X_embedded[list_filter(labels, 1),0], X_embedded[list_filter(labels, 1),1])
plt.legend(['not protest','protest'])
plt.title('t-SNE visualization from TF-IDF weighting on en-train data.')
plt.savefig('en-tfidf-tsne.png')
plt.show()

# %%
df = pd.DataFrame(X_embedded, columns = ['dim-0','dim-1'])

plt.figure(figsize=(16,10))
legend_map = {0: 'not protest',
              1: 'protest',
              }
fig = sns.scatterplot(
    x='dim-0',y='dim-1',
    # x="pca-one", y="pca-two",
    hue= np.vectorize(legend_map.__getitem__)(labels),
    palette=sns.color_palette("dark", 2),
    data=df,
    legend='full',
    alpha=0.75
)
plt.title('t-SNE visualization from TF-IDF weighting on en-train data.')
plt.savefig('sns_en-tfidf-tsne.png')
plt.show()

# %%
data = []
with open('es-train.json','r') as fp:
    for f in fp:
        data.append(json.loads(f))

# %%
corpus = [d['text'] for d in data]

vectorizer = TfidfVectorizer()

X = vectorizer.fit_transform(corpus)

labels = [d['label'] for d in data]

labels = np.asarray(labels)

# %%
sum(labels)/len(labels)
# Out:
# 0.131

# %%
X_embedded = TSNE(n_components=2, learning_rate='auto',
...                   init='random', perplexity=30).fit_transform(X)

# %%
X_embedded.shape
# Out:
# (1000, 2)

# %%
plt.scatter(X_embedded[list_filter(labels, 0),0], X_embedded[list_filter(labels, 0),1])
plt.scatter(X_embedded[list_filter(labels, 1),0], X_embedded[list_filter(labels, 1),1])
plt.legend(['not protest','protest'])
plt.title('t-SNE visualization from TF-IDF weighting on es-train data.')
plt.savefig('es-tfidf-tsne.png')
plt.show()

# %%
df = pd.DataFrame(X_embedded, columns = ['dim-0','dim-1'])

plt.figure(figsize=(16,10))
legend_map = {0: 'not protest',
              1: 'protest',
              }
fig = sns.scatterplot(
    x='dim-0',y='dim-1',
    # x="pca-one", y="pca-two",
    hue= np.vectorize(legend_map.__getitem__)(labels),
    palette=sns.color_palette("dark", 2),
    data=df,
    legend='full',
    alpha=0.75
)
plt.title('t-SNE visualization from TF-IDF weighting on es-train data.')
plt.savefig('sns_es-tfidf-tsne.png')
plt.show()

# %%
data = []
with open('pr-train.json','r') as fp:
    for f in fp:
        data.append(json.loads(f))

# %%
corpus = [d['text'] for d in data]

vectorizer = TfidfVectorizer()

X = vectorizer.fit_transform(corpus)

labels = [d['label'] for d in data]

labels = np.asarray(labels)

# %%
sum(labels)/len(labels)
# Out:
# 0.1324815063887021

# %%
X_embedded = TSNE(n_components=2, learning_rate='auto',
...                   init='random', perplexity=30).fit_transform(X)

# %%
X_embedded.shape
# Out:
# (1487, 2)

# %%
plt.scatter(X_embedded[list_filter(labels, 0),0], X_embedded[list_filter(labels, 0),1])
plt.scatter(X_embedded[list_filter(labels, 1),0], X_embedded[list_filter(labels, 1),1])
plt.legend(['not protest','protest'])
plt.title('t-SNE visualization from TF-IDF weighting on pt-train data.')
plt.savefig('pt-tfidf-tsne.png')
plt.show()

# %%
df = pd.DataFrame(X_embedded, columns = ['dim-0','dim-1'])

plt.figure(figsize=(16,10))
legend_map = {0: 'not protest',
              1: 'protest',
              }
fig = sns.scatterplot(
    x='dim-0',y='dim-1',
    # x="pca-one", y="pca-two",
    hue= np.vectorize(legend_map.__getitem__)(labels),
    palette=sns.color_palette("dark", 2),
    data=df,
    legend='full',
    alpha=0.75
)
plt.title('t-SNE visualization from TF-IDF weighting on pt-train data.')
plt.savefig('sns_pt-tfidf-tsne.png')
plt.show()

# %%
data = []
with open('en-train.json','r') as fp:
    for f in fp:
        data.append(json.loads(f))
with open('es-train.json','r') as fp:
    for f in fp:
        data.append(json.loads(f))
with open('pr-train.json','r') as fp:
    for f in fp:
        data.append(json.loads(f))

# %%
corpus = [d['text'] for d in data]

vectorizer = TfidfVectorizer()

X = vectorizer.fit_transform(corpus)

labels = [d['label'] for d in data]

labels = np.asarray(labels)

# %%
sum(labels)/len(labels)
# Out:
# 0.18965371264075861

# %%
X_embedded = TSNE(n_components=2, learning_rate='auto',
...                   init='random', perplexity=30).fit_transform(X)

# %%
X_embedded.shape
# Out:
# (11811, 2)

# %%
plt.scatter(X_embedded[list_filter(labels, 0),0], X_embedded[list_filter(labels, 0),1])
plt.scatter(X_embedded[list_filter(labels, 1),0], X_embedded[list_filter(labels, 1),1])
plt.legend(['not protest','protest'])
plt.title('t-SNE visualization from TF-IDF weighting on en-es-pt-train data.')
plt.savefig('en-es-pt-tfidf-tsne.png')
plt.show()

# %%
X.shape
# Out:
# (11811, 93704)

# %%
df = pd.DataFrame(X_embedded, columns = ['dim-0','dim-1'])

plt.figure(figsize=(16,10))
legend_map = {0: 'not protest',
              1: 'protest',
              }
fig = sns.scatterplot(
    x='dim-0',y='dim-1',
    # x="pca-one", y="pca-two",
    hue= np.vectorize(legend_map.__getitem__)(labels),
    palette=sns.color_palette("dark", 2),
    data=df,
    legend='full',
    alpha=0.75
)
plt.title('t-SNE visualization from TF-IDF weighting on en-es-pt-train data.')
plt.savefig('sns_en-es-pt-tfidf-tsne.png')
plt.show()
